# %%
#Navya Bhargava
#PRN- 25070123079
#Experiment 2-Study of list in Python
list1 = ["Apple","Banana","Orange"]
print(list1)
# Out:
# ['Apple', 'Banana', 'Orange']

# %%
list2 = [2,2.3,"Navya",True]
print(list2)
# Out:
# [2, 2.3, 'Navya', True]

# %%
list3 = ["Apple","Orange","Apple","Cherry"]
print(list3)
# Out:
# ['Apple', 'Orange', 'Apple', 'Cherry']

# %%
list4=["Apple","Banana","Orange","Cherry","Mango","Kiwi"]
print(list4[2])
print(list4[-3])
print(list4[2:5])
print(list4[:4])
print(list4[2:])
# Out:
# Orange
# Cherry
# ['Orange', 'Cherry', 'Mango']
# ['Apple', 'Banana', 'Orange', 'Cherry']
# ['Orange', 'Cherry', 'Mango', 'Kiwi']

# %%
list5=["Apple","Orange","Mango"]
list5[1] = 2
print(list5)
# Out:
# ['Apple', 2, 'Mango']

# %%
list6=["Apple","Orange","Cherry"]
list6.append("Mango")
print(list6)
# Out:
# ['Apple', 'Orange', 'Cherry', 'Mango']

# %%
list7=["Apple","Banana","Orange"]
list7.insert(1,"Mango)")
print(list7)
# Out:
# ['Apple', 'Mango)', 'Banana', 'Orange']

# %%
list8=["Apple","Banana","Orange"]
list9=["Kiwi","Mango"]
list8.extend(list9)
print(list8)
print(list9)
# Out:
# ['Apple', 'Banana', 'Orange', 'Kiwi', 'Mango']
# ['Kiwi', 'Mango']

# %%
marks=[90,82,66,76,33]
print(max(marks))
print(min(marks))
print(len(marks))
print(sum(marks))
print(sum(marks)/len(marks))
print(sorted(marks))
# Out:
# 90
# 33
# 5
# 347
# 69.4
# [33, 66, 76, 82, 90]

# %%
grocery=["Eggs","Milk","Cheese","Butter","Wheat"]
grocery.append("Dal")
grocery.remove("Butter")
grocery.remove("Cheese")
print(grocery)
# Out:
# ['Eggs', 'Milk', 'Wheat', 'Dal']
